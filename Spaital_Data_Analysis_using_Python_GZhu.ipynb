# %% [markdown]
# # Spatial Data Analysis using Python
# ### *Guimin Zhu*
# ### *March 1, 2024*
#
# Data:
# - UFO observation data (csv): https://raw.githubusercontent.com/august-zhu/GEOG376/main/ufo.csv
# - US county boundary data (GeoJSON): https://raw.githubusercontent.com/august-zhu/GEOG376/main/us_counties.geojson
#
# You can read in these data using `pandas.read_csv()` and `geopandas.read_file()`

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Task 1: Read in the datasets and filter the UFO observed in Florida
# Hint:
# - You can filter the ```STATE``` column in the GeoJSON data to be ```Fla.```

# %%
# Read in the 2 datasets

# %%
# Make UFO dataset a GeoDataFrame

# %%
# Filter the counteis to Florida only

# %%
# Filter the UFO observed in Florida

# %% [markdown]
# ## Task 2: Plot the map of UFO observations in Florida

# %% [markdown]
# ## Task 3: Plot a choropleth map of the numbers of UFO observations in Florida counties
# Hint:
# - Use the ```dataframe.groupby()``` method to group the same values in a column together
# - Use the ```missing_kwds``` parameter in ```geodataframe.plot()``` method to plot the NaN values

# %%
# Spatial join to get the county for each UFO observation

# %%
# Group by GEOID to get the counts

# %%
# Join the counts back to counties

# %%
# Plot the choropleth map
